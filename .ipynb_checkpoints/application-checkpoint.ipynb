# %%
import pandas as pd
import matplotlib.pyplot as p

# %%
df = pd.read_csv('survey_results_public.csv')
testing_df = df.copy(deep=True)
testing_df2 = df.copy(deep=True)
testing_df.shape
# Out:
# (51392, 154)

# %% [markdown]
# <h2>Education vs Salary: How education may influence the salary?</h2>

# %%
a = df.groupby(['FormalEducation']).mean().reset_index()
ax = a.plot.barh(x='FormalEducation', y='Salary')

# %% [markdown]
# <h2>years of experience vs. salary</h2>

# %%
b = df.groupby(['YearsProgram']).mean().reset_index()

# %%
ax = b.plot.barh(x='YearsProgram', y='Salary')

# %% [markdown]
# <h2> No. of Language vs. Salary </h2>

# %%
testing_df['LanguageCount'] = testing_df['HaveWorkedLanguage'].str.count(';') + 1

# %%
testing_df.dropna(subset=['LanguageCount'], inplace=True)

# %%
testing_df.reset_index(drop=True, inplace=True)

# %%
testing_df.shape
# Out:
# (36625, 155)

# %%
c = testing_df.groupby(['LanguageCount']).mean().reset_index()
c.dropna(subset=['Salary'], inplace=True)
c.reset_index(drop=True, inplace=True)

# %%
q = c["Salary"].quantile(0.1)

# %%
c= c[c["Salary"] > q].head(10)
print('Average Salary', c['Salary'].mean())
ax = c.plot.bar(x='LanguageCount', y='Salary', rot=0)
# Out:
# Average Salary 57044.46114557163

# %%
searchfor = ['Gender non-conforming', 'Transgender; Gender non-conforming','Gender non-conforming; Other', 'Transgender; Other', 'Transgender', 'Other', 'Male; Female']
testing_df2.dropna(subset=['Gender'], inplace=True)
testing_df2 = testing_df2[~testing_df2.Gender.str.contains('|'.join(searchfor))]
testing_df2['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
testing_df2.reset_index(drop=True, inplace=True)
testing_df2.drop(['Respondent'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-a3e3f7b0773c> in <module>
#       1 testing_df2.reset_index(drop=True, inplace=True)
# ----> 2 testing_df2.drop(['Respondent'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
testing_df2
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               7  Professional non-developer who sometimes write...
# 5               8                             Professional developer
# 6               9                             Professional developer
# 7              10                             Professional developer
# 8              11  Professional non-developer who sometimes write...
# 9              13                Used to be a professional developer
# 10             14                             Professional developer
# 11             15                             Professional developer
# 12             16                             Professional developer
# ...
